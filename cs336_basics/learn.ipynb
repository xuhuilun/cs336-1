# %%
'苹果'.encode('utf-8')
# Out:
# b'\xe8\x8b\xb9\xe6\x9e\x9c'

# %%
'苹'.encode('utf-8')
# Out:
# b'\xe8\x8b\xb9'

# %%
'果'.encode('utf-8')
# Out:
# b'\xe6\x9e\x9c'

# %%
import torch
s = 3
mask = torch.tril(torch.randn(s, s))

mask
# Out:
# tensor([[ 0.4844,  0.0000,  0.0000],
#         [ 0.1999, -0.6582,  0.0000],
#         [ 0.4603, -0.0658,  0.8209]])
